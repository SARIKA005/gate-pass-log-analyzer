# %%
import pandas as pd
df = pd.read_excel(r"c:\Users\sarik\Downloads\GatePass_Log_100 (1).xlsx")
df["Gate"] = df["Gate"].astype("Int64")

print(df.head())
print(df.columns)
print(df.info())
print(df.isnull().sum())
# Out:
#   Sno.     Visitor Name        DOB                           Purpose of Visit  \
# 0    1     Matthew Rana 1990-09-28               Attending a training session
# 1    2     Girindra Pal 1987-04-08           Family Visit - Employee Quarters
# 2    3  Baljiwan Chadha 1979-08-29  Business discussion with plant management
# 3    4  Wridesh Chhabra 1985-08-24                  Servicing plant equipment
# 4    5     Jatin Kapoor 1989-09-15          Advisory visit - technical matter
#
#    Gate  vehicle_no entry_time exit_time          id_type            id_no  \
# 0     3  CG04VC1950   15:24:00  19:21:00  Company ID Card      BSP4517SAIL
# 1     4  CG07PK4622   15:20:00  16:12:00      Aadhar Card     824628194821
# 2     4  MP09LI8424   08:00:00  12:42:00         Voter ID       HUS3194875
# 3     3  CG32BR6140   17:37:00  21:45:00         Voter ID       SPP7114710
# 4     3         NaN   18:36:00  21:02:00  Driving License  CG0620102964541
#
#   visit_date
# 0 2026-07-11
# 1 2026-05-07
# ...
